# %%
# %load_ext autoreload
# %autoreload 2

# %%
from MapEnvironment import MapEnvironment
from RRTMotionPlanner import RRTMotionPlanner
import numpy as np
from AdaptiveSampler2D import AdaptiveSampler2D
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
map_env = MapEnvironment("map.json", origin='center', sampler_resolution=0.025)
# [[], [], [], []]
# [[4, 9.5], [5.75, 10], [5.75, 11.5], [4, 12]],

# %%
map_env.draw_config_space(resolution=0.025)
# Out:
# ratio of free space to total space: 0.7009479717813052

# %%
map_env.draw_sampled_config_space(iterations=1000, print_every=100, draw_decision_regions=True) #h=0.7
# Out:
# drawing the config space
# running the sampler for 1000 iterations
# iter 0
# iter 100
# iter 200
# iter 300
# iter 400
# iter 500
# iter 600
# iter 700
# iter 800
# iter 900
# drawing decision regions
# 854

# %%
map_env_low_res85 = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.85
map_env_low_res85.draw_sampled_config_space(iterations=2500, print_every=250, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 2500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# iter 2250
# drawing decision regions
# 2070

# %%
map_env_low_res75 = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.75
map_env_low_res75.draw_sampled_config_space(iterations=2500, print_every=250, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 2500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# iter 2250
# drawing decision regions
# 2040

# %%
map_env_low_res65 = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.65
map_env_low_res65.draw_sampled_config_space(iterations=2500, print_every=250, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 2500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# iter 2250
# drawing decision regions
# 2034

# %%
map_env_low_resUniform = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h doesn't matter
map_env_low_resUniform.draw_sampled_config_space(iterations=2500, print_every=250, uniform=True, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 2500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# iter 2250
# drawing decision regions
# 1627

# %%
map_env_low_res55 = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.55
map_env_low_res55.draw_sampled_config_space(iterations=2500, print_every=250, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 2500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# iter 2250
# drawing decision regions
# 1999

# %%
map_env_low_res95 = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.95
map_env_low_res95.draw_sampled_config_space(iterations=2500, print_every=250, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 2500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# iter 2250
# drawing decision regions
# 2078

# %%
map_env_final = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.7
map_env_final.draw_sampled_config_space(iterations=7500, print_every=250, uniform=False, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 7500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# iter 2250
# iter 2500
# iter 2750
# iter 3000
# iter 3250
# iter 3500
# iter 3750
# iter 4000
# iter 4250
# iter 4500
# iter 4750
# iter 5000
# iter 5250
# iter 5500
# iter 5750
# iter 6000
# iter 6250
# iter 6500
# iter 6750
# iter 7000
# iter 7250
# drawing decision regions
# 4872

# %%
map_env_final = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.7
map_env_final.draw_sampled_config_space(iterations=7500, print_every=250, uniform=False, draw_decision_regions=True)
# Out:
# drawing the config space
# running the sampler for 7500 iterations
# iter 0
# iter 250
# iter 500
# iter 750
# iter 1000
# iter 1250
# iter 1500
# iter 1750
# iter 2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 map_env_final = MapEnvironment("map.json", origin='center', sampler_resolution=0.05) #h=0.7
# ----> 2 map_env_final.draw_sampled_config_space(iterations=7500, print_every=250, uniform=False, draw_decision_regions=True)
#
# File ~/Documents/Winter 23:24/Algo Motion Planning/Final Project/code - github/code/MapEnvironment.py:440, in MapEnvironment.draw_sampled_config_space(self, iterations, print_every, uniform, draw_decision_regions)
#     438 print(f"running the sampler for {iterations} iterations")
#     439 # sampler = AdaptiveSampler2D(resolution=resolution, legal_config_func=self.config_validity_checker)
# ...

# %%
planner = RRTMotionPlanner(planning_env=map_env, ext_mode="E2", goal_prob=0.1)

# %%
plan = planner.plan()
plan

# %%
plan = np.array([[1.8,-1.5], [1.8, -4]])
plan

# %%
planner.planning_env.visualize_plan(plan)

# %%
sampler = AdaptiveSampler2D(legal_config_func=map_env.config_validity_checker)
# print(sampler.pdf)
sampler.run(num_iterations=20)
