# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from MapEnvironment import MapEnvironment
import numpy as np

# %%
map_env = MapEnvironment("map_mp.json", origin='center')
# [[], [], [], []]

# %%
map_env.draw_config_space()
