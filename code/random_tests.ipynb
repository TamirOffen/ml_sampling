# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from MapEnvironment import MapEnvironment
import numpy as np
# [[100,100], [120,100], [120,120], [100,120]]

# %%
map_env = MapEnvironment("map_mp.json", origin='center')

# %%
start_config = np.array([3, -1.5])
goal_config = np.array([3, 0])
map_env.edge_validity_checker(start_config, goal_config)
# Out:
# False
